# %%
import sqlite3
import pandas as pd

# %%
# Specify the full path to the .db file on your drive
db_file_path = "/content/drive/MyDrive/eng_subtitles_database.db"

# Connect to the SQLite database
conn = sqlite3.connect(db_file_path)

# Read the data from the database
cursor = conn.cursor()
cursor.execute("SELECT * FROM zipfiles")
data = cursor.fetchall()

# Decode the content using latin-1 encoding
decoded_data = [(row[0], row[1], row[2].decode('latin-1')) for row in data]

# Now, decoded_data contains the decoded content

# %%
cursor.execute("PRAGMA table_info('zipfiles')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])
# Out:
# num
# name
# content

# %%
df = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...

# %%
df.shape
# Out:
# (82498, 3)

# %%
import zipfile
import io

count = 0

def decode_method(binary_data):
    global count
    # Decompress the binary data using the zipfile module
    print(count, end=" ")
    count += 1
    with io.BytesIO(binary_data) as f:
        with zipfile.ZipFile(f, 'r') as zip_file:
            # Assuming there's only one file in the ZIP archive
            subtitle_content = zip_file.read(zip_file.namelist()[0])

    # Now 'subtitle_content' should contain the extracted subtitle content
    return subtitle_content.decode('latin-1')  # Assuming the content is UTF-8 encoded text

# %%
# Sample 30% of the DataFrame
#sampled_df = df.sample(frac=0.5, random_state=42)
sampled_df = df.sample(frac=0.3, random_state=42)  # Use random_state for reproducibility

# Apply the function to the 'content' column in the sampled DataFrame
sampled_df['file_content'] = sampled_df['content'].apply(decode_method)

# %%
sampled_df.shape
# Out:
# (24749, 4)

# %%
sampled_df.iloc[0,:]
# Out:
# num                                                       9251120
# name                               maybe.this.time.(2014).eng.1cd
# content         b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x89\x9a\x...
# file_content    ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# Name: 17262, dtype: object

# %%
print(sampled_df.head())
# Out:
#            num                                               name  \
# 17262  9251120                     maybe.this.time.(2014).eng.1cd
# 7294   9211589  down.the.shore.s01.e10.and.justice.for.all.(19...
# 47707  9380845  uncontrollably.fond.s01.e07.heartache.(2016).e...
# 29914  9301436  screen.two.s13.e04.the.precious.blood.(1996).e...
# 54266  9408707                          battlebots.(2015).eng.1cd
#
#                                                  content  \
# 17262  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x89\x9a\x...
# 7294   b'PK\x03\x04\x14\x00\x00\x00\x08\x007\x8f\x99V...
# 47707  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x8f\x19\x...
# 29914  b'PK\x03\x04\x14\x00\x00\x00\x08\x00[\xaa\x99V...
# 54266  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf4<\x9aV...
#
#                                             file_content
# 17262  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# 7294   1\r\n00:00:09,275 --> 00:00:11,876\r\n¶ Oh, I ...
# ...

# %%
print(sampled_df.tail())
# Out:
#            num                                               name  \
# 67460  9458807    kevin.can.wait.s01.e13.ring.worm.(2017).eng.1cd
# 15296  9244890            bia.s01.e29.episode.1.29.(2019).eng.1cd
# 40242  9345965  heroes.s02.e11.chapter.eleven.powerless.(2007)...
# 56391  9417351  hot.in.cleveland.s05.e09.bad.george.clooney.(2...
# 67859  9460606  silk.stalkings.s04.e18.i.know.what.scares.you....
#
#                                                  content  \
# 67460  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xebP\x9aV...
# 15296  b'PK\x03\x04\x14\x00\x00\x00\x08\x00:\x99\x99V...
# 40242  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x85\r\x9a...
# 56391  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x891\x9aV...
# 67859  b'PK\x03\x04\x14\x00\x00\x00\x08\x00VR\x9aV8q\...
#
#                                             file_content
# 67460  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 15296  ï»¿1\r\n00:00:03,440 --> 00:00:06,160\r\n-Wher...
# ...

# %%
sampled_df.isnull().sum()
# Out:
# num             0
# name            0
# content         0
# file_content    0
# dtype: int64

# %%
# Save DataFrame to CSV with escape character specified
sampled_df.to_csv('data.csv', index=False, escapechar='\\')

# %%
sampled_df.iloc[0,1]
# Out:
# 'maybe.this.time.(2014).eng.1cd'

# %%
sampled_df.iloc[0,3]
# Out:
# 'ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch any video online with Open-SUBTITLES\r\nFree Browser extension: osdb.link/ext\r\n\r\n2\r\n00:00:37,328 --> 00:00:39,706\r\n<i>It could\'ve been\r\njust another summer.</i>\r\n\r\n3\r\n00:00:40,790 --> 00:00:43,042\r\n<i>But as I set foot on the sand,</i>\r\n\r\n4\r\n00:00:43,209 --> 00:00:46,212\r\n<i>that summer\r\nsuddenly felt different.</i>\r\n\r\n5\r\n00:00:55,221 --> 00:00:56,973\r\n<i>Like it was going to be the summer</i>\r\n\r\n6\r\n00:00:57,098 --> 00:00:59,142\r\n<i>that would change my life.</i>\r\n\r\n7\r\n00:00:59,350 --> 00:01:01,770\r\n<i>The summer of freedom.</i>\r\n\r\n8\r\n00:01:02,562 --> 00:01:05,607\r\n<i>The summer of\r\nendless possibilities.</i>\r\n\r\n9\r\n00:01:06,274 --> 00:01:09,402\r\n<i>The summer of 2007.</i>\r\n\r\n10\r\n00:01:16,493 --> 00:01:18,036\r\nOoh, aah!\r\n\r\n11\r\n00:01:24,459 --> 00:01:26,169\r\nOoh, oh!\r\n\r\n12\r\n00:01:26,377 --> 00:01:28,254\r\n<i>â\x99ª Oh, oh, ooh â\x99ª</i>\r\n\r\n1
# ...

# %%
import pandas as pd
include_columns = ['num', 'name', 'file_content']
df = pd.read_csv('data.csv', usecols=include_columns)

# %%
print(df.head())
# Out:
#        num                                               name  \
# 0  9251120                     maybe.this.time.(2014).eng.1cd
# 1  9211589  down.the.shore.s01.e10.and.justice.for.all.(19...
# 2  9380845  uncontrollably.fond.s01.e07.heartache.(2016).e...
# 3  9301436  screen.two.s13.e04.the.precious.blood.(1996).e...
# 4  9408707                          battlebots.(2015).eng.1cd
#
#                                         file_content
# 0  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# 1  1\r\n00:00:09,275 --> 00:00:11,876\r\n¶ Oh, I ...
# 2  1\r\n00:00:07,140 --> 00:00:14,220\r\n<i>Timin...
# 3  1\r\n00:00:06,133 --> 00:00:08,900\r\n[etherea...
# 4  ï»¿1\r\n00:00:01,480 --> 00:00:03,570\r\n[Chri...

# %%
print(df.tail())
# Out:
#            num                                               name  \
# 24744  9458807    kevin.can.wait.s01.e13.ring.worm.(2017).eng.1cd
# 24745  9244890            bia.s01.e29.episode.1.29.(2019).eng.1cd
# 24746  9345965  heroes.s02.e11.chapter.eleven.powerless.(2007)...
# 24747  9417351  hot.in.cleveland.s05.e09.bad.george.clooney.(2...
# 24748  9460606  silk.stalkings.s04.e18.i.know.what.scares.you....
#
#                                             file_content
# 24744  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 24745  ï»¿1\r\n00:00:03,440 --> 00:00:06,160\r\n-Wher...
# 24746  ï»¿1\r\n00:00:01,101 --> 00:00:02,865\r\n<i>Pr...
# 24747  ï»¿1\r\n00:00:01,768 --> 00:00:03,168\r\n<i>- ...
# 24748  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
